# %% [markdown]
# Link to GitHub Repository: https://github.com/Xfinitious/DSCI_V-100-Project

# %% [markdown]
# # The Data: <br>
# ### players.csv
#
# <p style="font-size: 16px;">
#     - experience: <br>
#     - subscribe: <br>
#     - hashedEmail: <br>
#     - played_hours: <br>
#     - name: <br>
#     - gender: <br>
#     - Age:
# </p>
#
# ### sessions.csv

# %% [markdown]
# TEXT

# %%
#CODE
